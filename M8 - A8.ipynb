# %% [markdown]
# # Assignment 8

# %% [markdown]
# The data used in this assighment is provided by V. Lohweg. "Banknote Authentication," UCI Machine Learning Repository, 2012. [Online]. Available: https://doi.org/10.24432/C55P57.

# %%
import pandas as pd  
from sklearn.model_selection import train_test_split  
from sklearn.tree import DecisionTreeClassifier

# %%
column_names = ["Variance", "Skewness", "Curtosis", "Entropy", "Class"]  
df = pd.read_csv("data_banknote_authentication.txt", header=None, names=column_names)  
  
print(df.head())
# Out:
#    Variance  Skewness  Curtosis  Entropy  Class
# 0   3.62160    8.6661   -2.8073 -0.44699      0
# 1   4.54590    8.1674   -2.4586 -1.46210      0
# 2   3.86600   -2.6383    1.9242  0.10645      0
# 3   3.45660    9.5228   -4.0112 -3.59440      0
# 4   0.32924   -4.4552    4.5718 -0.98880      0

# %%
## 1 Split the dataset into 60% training set and 40% test set.

# %%
X = df.drop("Class", axis=1)  
y = df["Class"]  # target variable


X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.4, random_state=42)

# %% [markdown]
# ## 2
# Using scikit-learn’s DecisionTreeClassifier, train a supervised learning model that can be used to generate predictions for your data

# %%
dtc = DecisionTreeClassifier()  
dtc.fit(X_train, y_train)  

# Prediction using the model
results = pd.DataFrame({"Predicted": y_pred, "Actual": y_test})  
print(results)
# Out:
#      Predicted  Actual
# 430          0       0
# 588          0       0
# 296          0       0
# 184          0       0
# 244          0       0
# ..         ...     ...
# 273          0       0
# 906          1       1
# 362          0       0
# 2            0       0
# 6            0       0
#
# [549 rows x 2 columns]

# %% [markdown]
# ## 3
# Report the tree depth, number of leaves, feature importance, train score, and test score of the tree.

# %%
train_score = dtc.score(X_train, y_train)  
test_score = dtc.score(X_test, y_test)  
  
print("Tree depth:", dtc.tree_.max_depth)  
print("Number of leaves:", dtc.tree_.n_leaves)  
feature_importances = pd.DataFrame({"Feature": X.columns, "Importance": clf.feature_importances_})  
print("\nFeature importances:")  
print(feature_importances)  
print("\nTrain score:", train_score)  
print("Test score:", test_score)
# Out:
# Tree depth: 7
# Number of leaves: 27
#
# Feature importances:
#     Feature  Importance
# 0  Variance    0.608085
# 1  Skewness    0.231555
# 2  Curtosis    0.140974
# 3   Entropy    0.019385
#
# Train score: 1.0
# Test score: 0.9781420765027322
